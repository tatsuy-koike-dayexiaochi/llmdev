# %%
# 名前と年齢を格納する変数を用意
name = "山田太郎"
age = 25

# 自己紹介の内容
outputString=f"""はじめまして、 {name} と申します。
年齢は {age} 歳です。来年は {age+1} 歳になります。
よろしくお願いします。"""

# 結果を表示
print(outputString)
# Out:
# はじめまして、 山田太郎 と申します。
# 年齢は 25 歳です。来年は 26 歳になります。
# よろしくお願いします。
