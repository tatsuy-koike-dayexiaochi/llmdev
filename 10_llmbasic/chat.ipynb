# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ]
)

# レスポンスの表示
pprint(vars(response))
# Out:
# {'_request_id': 'req_34dfe538ca7b4a31b98c382914d5803f',
#  'choices': [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='言語モデルを使う上でのポイントはいくつかあります。以下にいくつかの重要な点を挙げます。\n\n1. **目的を明確にする**: 言語モデルを使用する目的を明確にしてください。例えば、文章生成、翻訳、要約、質問応答など、用途によって最適な使い方が異なります。\n\n2. **プロンプト設計**: モデルに与える入力（プロンプト）の設計が結果に大きな影響を与えます。具体的で明確な指示を与えることで、期待する出力を得やすくなります。\n\n3. **フィードバックループ**: 得られた結果を評価し、必要に応じてプロンプトを修正することで、モデルの出力を改善できます。\n\n4. **知識の限界**: 言語モデルには情報のアップデートが反映されていない場合があります。特に、最新の情報や特定の専門知識については注意が必要です。\n\n5. **倫理的配慮**: 言語モデルを使用する際の倫理的な側面も考慮することが重要です。生成された内容が誤解を生む可能性や、不適切な内容が含まれる可能性があるため、慎重な検査が求められます。\n\n6. **多様な活用方法**: 言語モデルは、ただの質問応答や文章生成だけでなく、アイデアのブレインストーミングや、クリエイティブな作業を支援するツールとしても利用可能です。\n\n7. **技術的制約**: モデルの性能や応答速度、使用するインフラストラクチャによっても、使用体験が変わるため、自分のニーズに合った技術的な選択をすることが重要です。\n\nこれらのポイントを意識して言語モデルを活用することで、より効果的に目的を達成できるでしょう。', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None, annotations=[]))],
#  'created': 1771481983,
#  'id': 'chatcmpl-DArfz6fb932HaFjwR0mUk08vJirEk',
#  'model': 'gpt-4o-mini-2024-07-18',
#  'object': 'chat.completion',
#  'service_tier': 'default',
#  'system_fingerprint': 'fp_b4f1283ee2',
#  'usage': CompletionUsage(completion_tokens=465, prompt_tokens=18, total_tokens=483, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))}

# %%
# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 言語モデルを使う上でのポイントはいくつかあります。以下にいくつかの重要な点を挙げます。
#
# 1. **目的を明確にする**: 言語モデルを使用する目的を明確にしてください。例えば、文章生成、翻訳、要約、質問応答など、用途によって最適な使い方が異なります。
#
# 2. **プロンプト設計**: モデルに与える入力（プロンプト）の設計が結果に大きな影響を与えます。具体的で明確な指示を与えることで、期待する出力を得やすくなります。
#
# 3. **フィードバックループ**: 得られた結果を評価し、必要に応じてプロンプトを修正することで、モデルの出力を改善できます。
#
# 4. **知識の限界**: 言語モデルには情報のアップデートが反映されていない場合があります。特に、最新の情報や特定の専門知識については注意が必要です。
#
# 5. **倫理的配慮**: 言語モデルを使用する際の倫理的な側面も考慮することが重要です。生成された内容が誤解を生む可能性や、不適切な内容が含まれる可能性があるため、慎重な検査が求められます。
#
# 6. **多様な活用方法**: 言語モデルは、ただの質問応答や文章生成だけでなく、アイデアのブレインストーミングや、クリエイティブな作業を支援するツールとしても利用可能です。
#
# 7. **技術的制約**: モデルの性能や応答速度、使用するインフラストラクチャによっても、使用体験が変わるため、自分のニーズに合った技術的な選択をすることが重要です。
#
# これらのポイントを意識して言語モデルを活用することで、より効果的に目的を達成できるでしょう。

# %%
# 役割や前提の設定
role = "あなたはマーケティング分野に精通したビジネスコンサルタントです。企業の成長をサポートするために、効果的なマーケティング戦略を提供します。"

# メッセージの設定
message = "新製品の発売に向けた効果的なマーケティング戦略を教えてください。"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": message},
    ],
)

# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 新製品の発売に向けた効果的なマーケティング戦略には、以下のようなステップがあります。
#
# ### 1. ターゲット市場の特定
# - **市場調査**: 潜在顧客がどのようなニーズを持っているか、競合がどのように対応しているかを把握します。
# - **ペルソナの作成**: ターゲット顧客のペルソナを具体的に描き、それに基づいた戦略を立てます。
#
# ### 2. ブランドメッセージの構築
# - **USP（ユニーク・セリング・プロポジション）**: 製品の特長や利点を明確にし、他社との違いを強調します。
# - **ストーリーテリング**: ブランドや製品に関する魅力的なストーリーを作成し、感情に訴えるメッセージを発信します。
#
# ### 3. マーケティングチャネルの選定
# - **デジタルマーケティング**: ソーシャルメディア、SEO、コンテンツマーケティング、メールマーケティングなど、オンラインプレゼンスを強化します。
# - **オフラインマーケティング**: 展示会、イベント、販促活動などを活用し、直接顧客との接点を増やします。
#
# ### 4. プリ・ローンチ活動
# - **ティーザーキャンペーン**: 発売前に製品のヒントやSneak Peekをシェアして興味を引きます。
# - **インフルエンサーとの提携**: 業界のインフルエンサーに事前に製品を試してもらい、そのレビューを共有してもらいます。
#
# ### 5. 発売イベントの計画
# - **ローンチイベント**: 製品の公式発表イベントを行い、メディア、インフルエンサー、顧客を招待します。
# - **ライブデモ**: 製品の使用方法や特長をライブで示し、フィードバックを聞きます。
#
# ### 6. 発売後のフォローアップ
# - **顧客の声を集める**: 購入者からのレビューやフィードバックを収集し、次の改善に役立てます。
# - **リターゲティング広告**: 製品を見たが購入しなかった潜在顧客に向けてターゲット広告を出すことで再アプローチします。
#
# ### 7. 継続的なマーケティング活動
# - **コンテンツアップデート**: 製品の使い方やケーススタディなどのコンテンツを作成し続けます。
# - **顧客ロイヤルティプログラム**: リピーターを獲得するために、特別割引やポイント制度を導入します。
#
# これらのステップを実行することで、新製品の発売を成功に導き、企業の成長を促進することができます。

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    temperature=1.4,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本には多くの魅力的な点があります。以下にいくつかの主要な特徴を紹介します。
#
# ### 1. 伝統と文化
# 日本の文化は、長い歴史に根ざしています。茶道、華道、書道などの伝統芸道がありますし、和装（着物）や祭り（神社の祭りや盆踊り）も魅力の一部です。
#
# ###
# --------------------
# 日本には多くの魅力がありますので、その一部をご紹介します。
#
# ### 1. **歴史と文化**
# 日本の歴史は非常に豊かで、神社や寺院、伝統的な文化遺産が数多く残っています。古都京都や奈良では、美しい景観や文化に触れることができます。また、茶道や花道、剣道などの伝統芸能オンライン レッスンを
# --------------------
# 日本は、豊かな歴史や文化、自然の美しさが融合したユニークな国です。以下に日本の魅力をいくつか紹介します。
#
# ### 1. 文化と伝統
# 日本は、数千年にわたる独自の文化と伝統を持っています。茶道や華道、和装（着物）をはじめ、日本の伝統的な儀式や行事は多様

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    presence_penalty=-2.0,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本には多くの魅力があります。以下にいくつかのポイントを紹介します。
#
# ### 1. 文化と伝統
# 日本の文化は非常に多様で、長い歴史を持っています。伝統的な祭りや行事、例えばお正月やひな祭り、花見などは、日本の文化の美しさを体験する素晴らしい機会です。また、和食（寿
# --------------------
# もちろん、日本の魅力は多岐にわたります。以下にいくつかのポイントを紹介します。
#
# 1. **自然の美**: 日本は四季がはっきりしており、それぞれの季節に美しい自然が楽しめます。春の桜、夏の緑、秋の紅葉、冬の雪景色は、国内外の観光客に愛されています。特に、富士山や
# --------------------
# もちろん、日本の魅力は多岐にわたります。以下にいくつかのポイントを挙げます。
#
# ### 1. 自然の美しさ
# 日本は四季がはっきりとしており、春の桜、夏の青い海、秋の紅葉、冬の雪景色と、各季節ごとに異なる美しさを楽しむことができます。特に、富士山や

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    presence_penalty=2.0,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本には多くの魅力がありますので、いくつかご紹介します。
#
# ### 1. 美しい自然
# 日本は四季がはっきりしており、それぞれの季節に美しい風景を楽しむことができます。春は桜、夏は緑豊かな山々と海、秋は紅葉、冬は雪景色が広がります。また、富士山や温泉地とい
# --------------------
# もちろんです！日本の魅力は多岐にわたりますが、いくつかのポイントを挙げてみます。
#
# ### 1. 自然の美しさ
# 日本には四季折々の美しい風景があります。春は桜、夏は緑豊かな山と海、秋は紅葉、冬は雪化粧した景色が楽しめます。また、富士山や沖縄のビーチなど
# --------------------
# もちろんです！日本は独自の文化、歴史、美しい自然、おいしい食べ物など、多くの魅力にあふれています。以下にいくつかのポイントを紹介します。
#
# ### 1. 歴史と文化
# - **神社や寺院**: 京都や奈良には古代の神社や寺院が数多く残っており、日本独特の伝統的な建築様式を見ることが

# %%
import tiktoken
from tiktoken.core import Encoding

# OpenAI APIの特定のモデルに対応するトークナイザーを取得
encoding: Encoding = tiktoken.encoding_for_model(MODEL_NAME) # o200k_base

# テキストをトークンIDのリストに変換
tokens = encoding.encode("こんにちは！")
tokens_count = len(tokens)

# トークンの長さとトークンIDを表示
print(f"{tokens_count=}")
print(f"{tokens=}")
# Out:
# tokens_count=2
# tokens=[95839, 3393]

# %%
# トークンの選択度合い
message = """
AさんとBさんで会話してください。
A:あ、Bさんだ。
B:
"""

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    max_tokens=100,
    n=3,
    logit_bias = {95839:8, 3393:8}
)

# 結果を表示
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# B:こんにちは！Aさん、元気ですか？
# --------------------
# B:こんにちは、Aさん！最近どうですか？
# --------------------
# B:こんにちは！Aさん、元気ですか？

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
stream = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    stream=True,
)

for chunk in stream:
    if chunk.choices:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")
# Out:
# 言語モデルを使用する際のポイントはいくつかあります。以下に重要な点を挙げます。
#
# 1. **明確なプロンプト**: モデルに対して明確で具体的なプロンプトを提供することで、より良い結果を得やすくなります。質問や指示が曖昧であると、期待する答えが得られないことがあります。
#
# 2. **コンテキストの提供**: 必要な文脈や背景情報を与えることで、モデルがその情報を基により適切な応答を生成しやすくなります。
#
# 3. **繰り返しのテストと修正**: モデルの初期応答が期待以下の場合、プロンプトを調整したり、異なるアプローチを試したりすることで、結果を改善できます。
#
# 4. **出力の検証**: モデルが生成した情報は必ずしも正確でないことがあります。特に専門的な情報や重要な決定に関わる場合は、結果を検証することが重要です。
#
# 5. **バイアスの理解**: 言語モデルは訓練データに基づいているため、バイアスや誤った認識が含まれることがあります。それを認識し、結果を批判的に考える姿勢が必要です。
#
# 6. **使用目的の明確化**: モデルを使用する目的やゴールを明確にし、それに応じた利用方法を選ぶことが重要です。たとえば、アイデアのブレインストーミング、文書の要約、質問応答など、目的によってプロンプトや利用方法が異なります。
#
# 7. **倫理的配慮**: 言語モデルを使用する際には、個人情報の保護やプライバシーを考慮し、倫理的に問題のない方法で使用することが求められます。
#
# これらのポイントを参考に、言語モデルを効果的に活用できると良いでしょう。
