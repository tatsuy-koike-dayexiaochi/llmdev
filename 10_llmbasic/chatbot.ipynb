# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# %%
# メッセージを格納するリスト
messages=[]

while(True):
    # ユーザーからの質問を受付
    message = input("メッセージを入力:")
    # 質問が入力されなければ終了
    if message.strip()=="":
        break
    print(f"質問:{message}")

    # メッセージにユーザーからの質問を追加
    messages.append({"role": "user", "content": message.strip()})
    # やりとりが8を超えたら古いメッセージから削除
    if len(messages) > 8:
        del_message = messages.pop(0)

    # APIへリクエスト
    stream = client.chat.completions.create(
        model=MODEL_NAME,
        messages=messages,
        stream=True,
    )

    # 言語モデルからの回答を表示
    response_message = ""
    for chunk in stream:
        if chunk.choices:
            next = chunk.choices[0].delta.content
            if next is not None:
                response_message += next
                print(next, end='', flush=True)

    # メッセージに言語モデルからの回答を追加
    messages.append({"role": "assistant", "content": response_message})

print("\n---ご利用ありがとうございました！---")
# Out:
# 質問:掛け算はできる?
# はい、掛け算ができます。計算したい数値を教えていただければ、計算します！質問:humuhumu
# 「humuhumu」は、ハワイの魚の一種である「フムフムヌクヌクアプアア」を指すことがあります。この魚の名前は非常に長いですが、一般に「フムフム」と略されることもあります。何か具体的なことについて知りたいですか？または、他に質問がありますか？質問:何を聞いてたっけ
# 「humuhumu」とだけおっしゃっていましたので、私はハワイの魚のことについてお話ししました。その前には掛け算ができるかどうかの質問がありました。何か特定のトピックについて続けたいことや、他の質問があれば教えてください！質問:ほほお
# 「ほほお」と興味を示していただき、嬉しいです！何か特定のトピックや質問についてお話ししたいことがあれば、お気軽にどうぞ。お手伝いできることがあれば教えてください！質問:ところでなんの話だっけ
# 最初に「humuhumu」という言葉についてお話ししましたが、それがハワイの魚「フムフムヌクヌクアプアア」を指していると紹介しました。その後、他の話題や質問に移ることができるか尋ねました。この話題が続けたいものであれば、または別の話題に移りたい場合は教えてください！質問:あれ最初に何か言ったような
# 申し訳ありませんが、具体的に何を最初におっしゃったかを記憶することはできません。ただ、「humuhumu」という言葉で会話を始めたことを記憶しています。その前に何かお話しされていた場合、よろしければ再度教えていただけると助かります！何か他にお答えできることがあれば、お知らせください。質問:どこまで覚えてますか
# このチャットの中でのやり取りは、現在のセッション内での会話に基づいてリコールできますが、前回の会話や過去のセッションの内容は記憶していません。そのため、今のセッションの内容についてお答えできますが、以前の話を振り返ることはできません。現在のトピックや質問に関してお手伝いできることがあれば教えてください！質問:掛け算はできる？
# はい、掛け算はできます！具体的な計算が必要でしたら、教えていただければ計算します。例えば、「7×8は？」や「15×6は？」など、どんな掛け算でも大丈夫です。どうぞお知らせください！質問:なんの話だっけ
# 最初に「humuhumu」という言葉についての話から始まり、その後に掛け算ができるかどうかの質問がありました。その流れでお話ししていましたが、もし何か特定のトピックや話題に戻りたい場合は教えてください！どのような方向に進めたいかお聞かせいただければと思います。質問:えっと、なんの話してたっけ
# 現在の会話では、最初に「ほほお」という言葉で始まり、その後に「掛け算はできる？」という質問がありました。ただ、具体的なトピックが他にあれば、どんなことでもお話しすることができますので、興味のある内容や質問があれば教えてください！質問:最初の会話はなんだっけ
# 申し訳ありませんが、このセッションの初めからの具体的な内容を正確に思い出すことはできません。ただし、あなたの「ほほお」という言葉を最初に引き合いに出したことに続いて、掛け算についての質問がありました。このセッション内での流れを覚えている限りでお答えしましたが、何か別の具体的な話題や質問があればぜひ教えてください！
# ---ご利用ありがとうございました！---
