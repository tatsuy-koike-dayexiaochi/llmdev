# %%
import urllib.request
import datetime
# 関数の仕様

# URLを引数として受け取り
# ファイル名を戻り値として返す
def save_url_content(url) -> str: 
    # Webページのコンテンツの先頭500文字を日時のファイル名で保存
    with urllib.request.urlopen(url) as response:
        data = response.read(5120)
    html = data.decode("utf-8")[:500]
    file_name = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    with open(file_name, "w", encoding="utf-8") as file:
        file.write(html)
    return file_name

# 呼び出し側の仕様
url = input("URLを入力してください: ")
file_name = save_url_content(url)
print(f"Content saved in: {file_name}")
# Out:
# Content saved in: 20260218_114745

# %%
# 指定したURLの先頭500文字が正しい日付フォーマットのファイル名で保存されていること
import re
file_name = save_url_content('https://techacademy.jp')

file_name_pattern = r"^\d{8}_\d{6}$"

assert re.match(pattern, file_name)

with open(file_name, encoding="utf-8") as file:
    content = file.read()

assert len(content) == 500
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 7
#       3 file_name = save_url_content('https://techacademy.jp')
#       5 file_name_pattern = r"^\d{8}_\d{6}$"
# ----> 7 assert file_name.exists()
#       8 assert re.match(pattern, file_name)
#      10 with open(file_name, encoding="utf-8") as file:
#
# AttributeError: 'str' object has no attribute 'exists'
